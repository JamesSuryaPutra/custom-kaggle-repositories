# %% [markdown]
# # Preparation

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt
import seaborn as sns

import plotly.graph_objs as go
import plotly.offline as py
import plotly.express as px

#Ignore warnings
import warnings
warnings.filterwarnings('ignore')

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/stable-diffusion-xl/pytorch/base-1-0/1/LICENSE.md
# /kaggle/input/stable-diffusion-xl/pytorch/base-1-0/1/model_index.json
# /kaggle/input/stable-diffusion-xl/pytorch/base-1-0/1/pipeline.png
# /kaggle/input/stable-diffusion-xl/pytorch/base-1-0/1/README.md
# /kaggle/input/stable-diffusion-xl/pytorch/base-1-0/1/sd_xl_base_1.0.safetensors
# /kaggle/input/stable-diffusion-xl/pytorch/base-1-0/1/sd_xl_offset_example-lora_1.0.safetensors
# /kaggle/input/stable-diffusion-xl/pytorch/base-1-0/1/01.png
# /kaggle/input/stable-diffusion-xl/pytorch/base-1-0/1/comparison.png
# /kaggle/input/stable-diffusion-xl/pytorch/base-1-0/1/sd_xl_base_1.0_0.9vae.safetensors
# /kaggle/input/stable-diffusion-xl/pytorch/base-1-0/1/.gitattributes
# /kaggle/input/stable-diffusion-xl/pytorch/base-1-0/1/tokenizer_2/merges.txt
# /kaggle/input/stable-diffusion-xl/pytorch/base-1-0/1/tokenizer_2/vocab.json
# /kaggle/input/stable-diffusion-xl/pytorch/base-1-0/1/tokenizer_2/tokenizer_config.json
# ...

# %% [markdown]
# # Install packages

# %%
# !pip install diffusers --upgrade
# !pip install invisible_watermark transformers accelerate safetensors
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.0/5.0 MB 67.0 MB/s eta 0:00:00:00:010:01
# ...
#   Attempting uninstall: diffusers
#     Found existing installation: diffusers 0.36.0
#     Uninstalling diffusers-0.36.0:
#       Successfully uninstalled diffusers-0.36.0
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 34.3 MB/s eta 0:00:0000:01
# ...

# %%
from diffusers import DiffusionPipeline
import torch
# Out:
# Flax classes are deprecated and will be removed in Diffusers v1.0.0. We recommend migrating to PyTorch classes or pinning your version of Diffusers.
# Flax classes are deprecated and will be removed in Diffusers v1.0.0. We recommend migrating to PyTorch classes or pinning your version of Diffusers.

# %%
from diffusers import DiffusionPipeline, EulerDiscreteScheduler
import torch
import matplotlib.pyplot as plt

pipe = DiffusionPipeline.from_pretrained("/kaggle/input/stable-diffusion-xl/pytorch/base-1-0/1", torch_dtype=torch.float16, use_safetensors=True, variant="fp16")
pipe.to("cuda")
# Out:
# ...
# Loading weights:   0%|          | 0/196 [00:00<?, ?it/s]
# StableDiffusionXLPipeline {
#   "_class_name": "StableDiffusionXLPipeline",
#   "_diffusers_version": "0.37.1",
#   "_name_or_path": "/kaggle/input/stable-diffusion-xl/pytorch/base-1-0/1",
#   "feature_extractor": [
#     null,
#     null
#   ],
#   "force_zeros_for_empty_prompt": true,
#   "image_encoder": [
#     null,
#     null
#   ],
#   "scheduler": [
#     "diffusers",
#     "EulerDiscreteScheduler"
#   ],
#   "text_encoder": [
#     "transformers",
#     "CLIPTextModel"
#   ],
#   "text_encoder_2": [
#     "transformers",
#     "CLIPTextModelWithProjection"
#   ],
#   "tokenizer": [
#     "transformers",
#     "CLIPTokenizer"
#   ],
#   "tokenizer_2": [
#     "transformers",
#     "CLIPTokenizer"
#   ],
#   "unet": [
#     "diffusers",
#     "UNet2DConditionModel"
#   ],
#   "vae": [
#     "diffusers",
#     "AutoencoderKL"
#   ]
# }

# %%
def generate(prompt):
    return pipe(prompt).images[0]

# %% [markdown]
# # Prompt generation test

# %%
prompt = "The cartoonized, anthropomorphic bee and butterfly participate in a tennis exhibition."
plt.imshow(generate(prompt))
# Out:
#   0%|          | 0/50 [00:00<?, ?it/s]

# %%
prompt = "The cartoonized, anthropomorphic dung beetle and grasshopper participate in a badminton exhibition."
plt.imshow(generate(prompt))
# Out:
#   0%|          | 0/50 [00:00<?, ?it/s]

# %%
prompt = "Two cartoonized, anthropomorphic ladybugs participate in a rally racing with their vehicle made from cardboard and wooden log wheels."
plt.imshow(generate(prompt))
# Out:
#   0%|          | 0/50 [00:00<?, ?it/s]

# %%
prompt = "A cartoonized, anthropomorphic moth participates in a circuit racing with a vehicle made from junk bathtub and wagon wheels."
plt.imshow(generate(prompt))
# Out:
#   0%|          | 0/50 [00:00<?, ?it/s]

# %%
prompt = "Two cartoonized, anthropomorphic spiders participate in a sidecar racing with their vehicle made from empty juice cartons and cucumber wheels."
plt.imshow(generate(prompt))
# Out:
#   0%|          | 0/50 [00:00<?, ?it/s]

# %%
prompt = "A cartoonized, anthropomorphic dragonfly participates in an oval racing with a vehicle made from empty matchbox and wooden wheels."
plt.imshow(generate(prompt))
# Out:
#   0%|          | 0/50 [00:00<?, ?it/s]
